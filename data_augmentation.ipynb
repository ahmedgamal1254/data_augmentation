# %%
import numpy as np
import tensorflow as tf
from keras.preprocessing.image import load_img,img_to_array,ImageDataGenerator
from tensorflow.keras.applications.resnet50 import preprocess_input

# %%
img=load_img('/content/bird.jpg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x399 at 0x7F97336E1110>

# %%
# convert image to array
data=img_to_array(img)
# data

# %%
sample=np.expand_dims(data,0)
# sample

# %%
# sample

# %%
data_generate=ImageDataGenerator(
    preprocessing_function=preprocess_input,
    horizontal_flip=True,
    width_shift_range = 0.2,
    height_shift_range = 0.2
)

# %%
new_data=data_generate.flow(sample,batch_size=9)

# %%
# new_data.next()

# %%
new_data.next().shape
# Out:
# (1, 399, 640, 3)

# %%
import matplotlib.pyplot as plt

# %%
for i in range(9):
  batch=new_data.next()
  image=batch[0].astype('uint8')
  plt.imshow(image)
plt.show()

# %%
data_generator_with_aug = ImageDataGenerator(preprocessing_function=preprocess_input,
                                   horizontal_flip=True,
                                   width_shift_range = 0.2,
                                   height_shift_range = 0.2)

train_generator = data_generator_with_aug.flow_from_directory(
        '/content/drive/MyDrive/img',
        target_size=(200,200),
        batch_size=24)
# Out:
# Found 1 images belonging to 2 classes.

# %%
# train_generator.next()

# %%
import os
import cv2
data=[]
for i in os.listdir('/content/images'):
  img=os.path.join(f'/content/images/{i}')
  img=plt.imread(img)
  img=cv2.resize(img,(200,200))
  print(plt.imshow(img))
  print(i)
plt.show()
# Out:
# AxesImage(54,36;334.8x217.44)
# FB_IMG_16099370434046573.jpg
# AxesImage(54,36;334.8x217.44)
# FB_IMG_16120096805155705.jpg
# AxesImage(54,36;334.8x217.44)
# FB_IMG_16120094342958348.jpg
# AxesImage(54,36;334.8x217.44)
# FB_IMG_16120130176345129 - Copy.jpg
# AxesImage(54,36;334.8x217.44)
# FB_IMG_16120130176345129.jpg
# AxesImage(54,36;334.8x217.44)
# 257764684_1099013250909596_726246993320965539_n - Copy.jpg
# AxesImage(54,36;334.8x217.44)
# 257764684_1099013250909596_726246993320965539_n.jpg
# AxesImage(54,36;334.8x217.44)
# FB_IMG_16120094342958348 - Copy.jpg
# AxesImage(54,36;334.8x217.44)
# FB_IMG_16120096805155705 - Copy.jpg
# AxesImage(54,36;334.8x217.44)
# FB_IMG_16099370434046573 - Copy.jpg

# %%
# load the image
img = load_img('bird.jpg')
# convert to numpy array
data = img_to_array(img)
# expand dimension to one sample
samples = np.expand_dims(data, 0)
# create image data augmentation generator
datagen = ImageDataGenerator(width_shift_range=[-200,200])
# prepare iterator
it = datagen.flow(samples, batch_size=1)
# generate samples and plot
for i in range(9):
	# define subplot
	plt.subplot(330 + 1 + i)
	# generate batch of images
	batch = it.next()
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	# plot raw pixel data
	plt.imshow(image)
# show the figure
plt.show()
